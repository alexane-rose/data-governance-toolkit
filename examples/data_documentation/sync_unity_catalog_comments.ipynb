# %% [markdown]
# # Examples on how to use the Data Data Governance Tooklkit Catalog Comment Sync functions
#
# **Description:** This notebook provides examples on how to use the Data Governance Tooklkit Unity Catalog Comment Sync functions

# %% [markdown]
# ## Sync table comments between catalogs

# %%
from data_governance_toolkit.data_documentation.sync_unity_catalog_comments import sync_table_column_comments, sync_schema_table_comments

# Example: Sync table comment/description in schema between environments
sync_table_column_comments(origin_catalog="my_catalog_dev",
    target_catalog="my_catalog_prod",
    table_schema= "my_schema",
    table_name = "my_table",
    spark = spark)

# %%
# Example: Sync all table comment/description in schema between environments
sync_schema_table_comments(origin_catalog="my_catalog_dev",
    target_catalog="my_catalog_prod",
    table_schema= "my_schema",
    spark = spark)

# %% [markdown]
# ## Sync table column comments between catalogs

# %%
from data_governance_toolkit.data_documentation.sync_unity_catalog_comments import sync_table_column_comments , sync_schema_column_comments

# Example: Sync column comments for a specific table
sync_table_column_comments(origin_catalog="my_catalog_dev",
    target_catalog="my_catalog_prod",
    table_schema="my_schema", 
    table_name="my_table", 
    spark=spark)

# %%
# Example: Sync column comments for all tables in schema
sync_schema_column_comments(origin_catalog="my_catalog_dev",
    target_catalog="my_catalog_prod",
    table_schema="my_schema", 
    spark=spark)
